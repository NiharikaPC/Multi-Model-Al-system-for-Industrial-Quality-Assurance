# %%
import sys
!"{sys.executable}" -m pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# %%
import torch

print("GPU Available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %% [markdown]
# **Testing with nano model**

# %%
# model = YOLO("yolov8n.pt")

# %%
'''
results = model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    workers=4,
    project="runs",
    name="yolov8n_neu"
)
'''
# Out:
# '\nresults = model.train(\n    data="data.yaml",\n    epochs=50,\n    imgsz=640,\n    batch=16,\n    device=0,\n    workers=4,\n    project="runs",\n    name="yolov8n_neu"\n)\n'

# %% [markdown]
# **Testing with small model**

# %%
model = YOLO("yolov8s.pt")

# %% [markdown]
# 50 epochs

# %%
'''
results = model.train(
    data="data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="yolov8s_neu"
)
'''
# Out:
# '\nresults = model.train(\n    data="data.yaml",\n    epochs=50,\n    imgsz=640,\n    batch=16,\n    name="yolov8s_neu"\n)\n'

# %%
name="yolov8s_neu"

# %% [markdown]
# 100 epochs

# %%
'''from ultralytics import YOLO

model = YOLO("runs/detect/yolov8s_neu-6/weights/last.pt")

model.train(resume=True)'''
# Out:
# 'from ultralytics import YOLO\n\nmodel = YOLO("runs/detect/yolov8s_neu-6/weights/last.pt")\n\nmodel.train(resume=True)'

# %%
'''results = model.train(
    data="data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    name="yolov8s_neu"
)'''
# Out:
# 'results = model.train(\n    data="data.yaml",\n    epochs=100,\n    imgsz=640,\n    batch=8,\n    name="yolov8s_neu"\n)'

# %%
'''# run 2
from ultralytics import YOLO

model = YOLO("runs/detect/yolov8s_neu/weights/last.pt")

model.train(resume=True)'''
# Out:
# Ultralytics 8.4.90  Python-3.11.9 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
'''# one more run
results = model.train(
    data="data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    name="yolov8s_neu"
)'''
# Out:
# '# one more run\nresults = model.train(\n    data="data.yaml",\n    epochs=100,\n    imgsz=640,\n    batch=8,\n    name="yolov8s_neu"\n)'

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/yolov8s_neu-6/weights/best.pt")

model.predict(
    source="valid/valid/images",
    save=True,
    conf=0.25
)
# Out:
# image 1/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\crazing_1.jpg: 640x640 1 crazing, 47.6ms
# image 2/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\crazing_2.jpg: 640x640 3 crazings, 51.2ms
# image 3/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\crazing_3.jpg: 640x640 (no detections), 49.7ms
# image 4/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\crazing_4.jpg: 640x640 2 crazings, 26.4ms
# image 5/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\crazing_5.jpg: 640x640 3 crazings, 26.3ms
# image 6/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\inclusion_1.jpg: 640x640 5 inclusions, 26.5ms
# image 7/30 c:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\images\inclusion_2.jpg: 640x640 3 inclusions, 26.1ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/yolov8s_neu-6/weights/best.pt")

metrics = model.val(data="data.yaml")
# Out:
# Ultralytics 8.4.90  Python-3.11.9 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 73 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 224.694.8 MB/s, size: 16.6 KB)
# val: Scanning C:\Users\Niharika Chandak\OneDrive\Desktop\SoC\Week 6 - CV Model\valid\valid\labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1s/it 2.3s6.8s
#                    all         30         64      0.766      0.751      0.831      0.492
#                crazing          5          8       0.57       0.25      0.668      0.264
#              inclusion          5         15      0.619        0.8      0.739      0.348
#                patches          5         17      0.888      0.933      0.973      0.653
# ...

# %%
print("Precision :", metrics.box.mp)
print("Recall    :", metrics.box.mr)
print("mAP@50    :", metrics.box.map50)
print("mAP@50-95 :", metrics.box.map)
# Out:
# Precision : 0.7656185683635736
# Recall    : 0.7511330811526645
# mAP@50    : 0.8312979866911933
# mAP@50-95 : 0.4915534697635276
